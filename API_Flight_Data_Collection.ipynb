# %%
import pandas as pd
import requests
from datetime import datetime

# %%
import accessKeys

# %% [markdown]
# # Acces to SQL Database

# %%
schema = "cities_database"
host = "localhost"
user = "root"
password = accessKeys.mySQL_password
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
cities_from_sql = pd.read_sql("city", con=connection_string)
city_df = cities_from_sql[["city_id", "city_name", "latitude", "longitude"]]

# %%
latitudes = city_df['latitude'].to_list()
longitudes = city_df['longitude'].to_list()
city_ids = city_df['city_id'].to_list()

# %% [markdown]
# # API

# %% [markdown]
# ## Get Airports

# %%
def Get_Airports_per_Location(lats,lons,city_ids):
    list_of_airport_dfs = []
    for lat,lon,city_id in zip(lats,lons,city_ids):

        url = "https://aerodatabox.p.rapidapi.com/airports/search/location"
        querystring = {"lat":lat,"lon":lon,"radiusKm":"50","limit":"10","withFlightInfoOnly":"true"}
        headers = {
            "x-rapidapi-key": accessKeys.API_airport_key,
            "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
        }
        response = requests.get(url, headers=headers, params=querystring)

        airport_df = pd.json_normalize(response.json()['items'])
        airport_df['city_id'] = city_id
        list_of_airport_dfs.append(airport_df)

    return pd.concat(list_of_airport_dfs,axis=0)

# %%
airport_df = Get_Airports_per_Location(lats=latitudes, lons=longitudes, city_ids=city_ids)

# %%
airport_df
# Out:
#    icao iata                              name                    shortName  \
# 0  EDDT  TXL                     Berlin -Tegel                       -Tegel
# 1  EDDB  BER                Berlin Brandenburg                  Brandenburg
# 0  EDDH  HAM                           Hamburg                      Hamburg
# 0  LFPB  LBG                 Paris -Le Bourget                  -Le Bourget
# 1  LFPO  ORY                       Paris -Orly                        -Orly
# 2  LFPG  CDG           Paris Charles de Gaulle            Charles de Gaulle
# 0  ESSB  BMA                 Stockholm -Bromma                      -Bromma
# 1  ESSA  ARN                Stockholm -Arlanda                     -Arlanda
# 0  RJTT  HND                             Tokyo                        Tokyo
# 0  LIRA  CIA       Roma Ciampino–G. B. Pastine       Ciampino–G. B. Pastine
# 1  LIRF  FCO  Rome Leonardo da Vinci–Fiumicino  Leonardo da Vinci–Fiumicino
# 0  LOWW  VIE                  Vienna Schwechat                    Schwechat
# 0  LOWI  INN                         Innsbruck                    Innsbruck
# 0  FACT  CPT                         Cape Town                    Cape Town
# 0  LFML  MRS                Marseille Provence                     Provence
#
#   municipalityName countryCode             timeZone  location.lat  \
# 0           Berlin          DE        Europe/Berlin      52.55970
# 1           Berlin          DE        Europe/Berlin      52.35139
# 0          Hamburg          DE        Europe/Berlin      53.63040
# 0            Paris          FR         Europe/Paris      48.96940
# 1            Paris          FR         Europe/Paris      48.72530
# 2            Paris          FR         Europe/Paris      49.01280
# 0        Stockholm          SE     Europe/Stockholm      59.35440
# 1        Stockholm          SE     Europe/Stockholm      59.65190
# 0            Tokyo          JP           Asia/Tokyo      35.55230
# 0             Roma          IT          Europe/Rome      41.79940
# 1             Rome          IT          Europe/Rome      41.80450
# 0           Vienna          AT        Europe/Vienna      48.11030
# 0        Innsbruck          AT        Europe/Vienna      47.26020
# 0        Cape Town          ZA  Africa/Johannesburg     -33.96480
# 0        Marseille          FR         Europe/Paris      43.43927
#
#    location.lon  city_id
# 0     13.287699        1
# 1     13.493889        1
# 0      9.988229        2
# 0      2.441390        3
# 1      2.359440        3
# 2      2.549999        3
# 0     17.941698        4
# 1     17.918600        4
# 0    139.780000        5
# 0     12.594900        6
# 1     12.250800        6
# 0     16.569700        7
# 0     11.343999        8
# 0     18.601700        9
# 0      5.221424       10

# %% [markdown]
# ## Get Flights

# %%
url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EHAM/2025-06-20T00:00/2025-06-20T12:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"false","withCodeshared":"false","withCargo":"false","withPrivate":"false","withLocation":"false"}

headers = {
	"x-rapidapi-key": accessKeys.API_flight_key,
	"x-rapidapi-host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'arrivals': [{'departure': {'airport': {'icao': 'GCLP', 'iata': 'LPA', 'name': 'Gran Canaria Island', 'timeZone': 'Atlantic/Canary'}, 'scheduledTime': {'utc': '2025-06-19 18:05Z', 'local': '2025-06-19 19:05+01:00'}, 'revisedTime': {'utc': '2025-06-19 17:57Z', 'local': '2025-06-19 18:57+01:00'}, 'terminal': '1', 'checkInDesk': '322-323', 'gate': 'C19', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-06-19 22:35Z', 'local': '2025-06-20 00:35+02:00'}, 'revisedTime': {'utc': '2025-06-19 22:03Z', 'local': '2025-06-20 00:03+02:00'}, 'runwayTime': {'utc': '2025-06-19 22:03Z', 'local': '2025-06-20 00:03+02:00'}, 'terminal': '1', 'baggageBelt': '6', 'runway': '06', 'quality': ['Basic', 'Live']}, 'number': 'HV 5666', 'callSign': 'TRA9Y', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'PH-YHA', 'modeS': '4866ED', 'model': 'Airbus A321-200 (Sharklets)'}, 'airline': {'name': 'Transavia', 'iata': 'HV', 'icao': 'TRA'}}, {'departure': {'airport': {'icao': 'GCFV', 'iata': 'FUE', 'name': 'Fuerteventura Island', 'timeZone': 'Atlantic/Canary'}, 'scheduledTime': {'utc': '2025-06-19 18:15Z', 'local': '2025-06-19 19:15+01:00'}, 'revisedTime': {'utc': '2025-06-19 18:09Z', 'local': '2025-06-19 19:09+01:00'}, 'terminal': '1', 'checkInDesk': '17-18', 'gate': 'A11', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-06-19 22:30Z', 'local': '2025-06-20 00:30+02:00'}, 'revisedTime': {'utc': '2025-06-19 22:08Z', 'local': '2025-06-20 00:08+02:00'}, 'runwayTime': {'utc': '2025-06-19 22:08Z', 'local': '2025-06-20 00:08+02:00'}, 'terminal': '1', 'baggageBelt': '4', 'runway': '06', 'quality': ['Basic', 'Live']}, 'number': 'HV 6706', 'callSign': 'TRA83Q', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'PH-YHY', 'modeS': '4866DE', 'model': 'Airbus A321-200 (Sharklets)'}, 'airline': {'name': 'Transavia', 'iata': 'HV', 'icao': 'TRA'}}, {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice', 'timeZone': 'Europe/Paris'}, 'scheduledTime': {'utc': '2025-06-19 20:35Z', 'local': '2025-06-19 22:35+02:00'}, 'terminal': '1', 'quality': ['Basic']}, 'arrival': {'scheduledTime': {'utc': '2025-06-19 22:35Z', 'local': '2025-06-20 00:35+02:00'}, 'revisedTime': {'utc': '2025-06-19 22:10Z', 'local': '2025-06-20 00:10+02:00'}, 'runwayTime': {'utc': '2025-06-19 22:10Z', 'local': '2025-06-20 00:10+02:00'}, 'terminal': '1', 'baggageBelt': '2', 'runway': '06', 'quality': ['Basic', 'Live']}, 'number': 'HV 5586', 'callSign': 'TRA5586', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'PH-HSK', 'modeS': '485122', 'model': 'Boeing 737-800 (winglets)'}, 'airline': {'name': 'Transavia', 'iata': 'HV', 'icao': 'TRA'}}, {'departure': {'airport': {'icao': 'BIKF', 'iata': 'KEF', 'name': 'Reykjavik', 'timeZone': 'Atlantic/Reykjavik'}, 'scheduledTime': {'utc': '2025-06-19 19:00Z', 'local': '2025-06-19 19:00+00:00'}, 'revisedTime': {'utc': '2025-06-19 19:19Z', 'local': '2025-06-19 19:19+00:00'}, 'runwayTime': {'utc': '2025-06-19 19:30Z', 'local': '2025-06-19 19:30+00:00'}, 'gate': 'A13', 'quality': ['Basic', 'Live']}, 'arrival': {'scheduledTime': {'utc': '2025-06-19 22:10Z', 'local': '2025-06-20 00:10+02:00'}, 'revisedTime': {'utc': '2025-06-19 22:12Z', 'local': '2025-06-20 00:12+02:00'}, 'runwayTime': {'utc': '2025-06-19 22:12Z', 'local': '2025-06-20 00:12+02:00'}, 'terminal': '1', 'baggageBelt': '4', 'quality': ['Basic', 'Live']}, 'number': 'HV 6886', 'callSign': 'TRA85K', 'status': 'Arrived', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'PH-HSI', 'modeS': '485009', 'model': 'Boeing 737-800 (winglets)'}, 'airline': {'name': 'Transavia', 'iata': 'HV', 'icao': 'TRA'}}, {'departure': {'airport': {'icao': 'LGKR', 'iata': 'CFU', 'name': 'Kerkyra Island', 'timeZone': 'Europe/Athens'}, 'scheduledTime': {'utc': '2025-06-19 19:25Z', 'local': '2025-06-19 22:25+03:00'}, 'quality': ['Basi ...

# %%
flights_df = pd.json_normalize(response.json()["arrivals"])

# %%
flights_df
# Out:
#       number callSign   status codeshareStatus  isCargo  \
# 0    HV 5666    TRA9Y  Arrived      IsOperator    False
# 1    HV 6706   TRA83Q  Arrived      IsOperator    False
# 2    HV 5586  TRA5586  Arrived      IsOperator    False
# 3    HV 6886   TRA85K  Arrived      IsOperator    False
# 4    HV 6598  TRA6598  Arrived      IsOperator    False
# ..       ...      ...      ...             ...      ...
# 265   KL 984   KLM50W  Arrived      IsOperator    False
# 266  KL 1088   KLM70Y  Arrived      IsOperator    False
# 267  HV 5794  TRA5794  Arrived      IsOperator    False
# 268  U2 7962  EJU46JE  Arrived      IsOperator    False
# 269   KL 758   KLM758  Arrived      IsOperator    False
#
#     departure.airport.icao departure.airport.iata departure.airport.name  \
# 0                     GCLP                    LPA    Gran Canaria Island
# 1                     GCFV                    FUE   Fuerteventura Island
# 2                     LFMN                    NCE                   Nice
# 3                     BIKF                    KEF              Reykjavik
# 4                     LGKR                    CFU         Kerkyra Island
# ..                     ...                    ...                    ...
# 265                   EGLC                    LCY                 London
# 266                   EGFF                    CWL                Cardiff
# 267                   LGPZ                    PVK        Preveza/Lefkada
# 268                   EPKK                    KRK                 Kraków
# 269                   MPTO                    PTY                Tocumen
#
#     departure.airport.timeZone departure.scheduledTime.utc  ...  \
# 0              Atlantic/Canary           2025-06-19 18:05Z  ...
# 1              Atlantic/Canary           2025-06-19 18:15Z  ...
# 2                 Europe/Paris           2025-06-19 20:35Z  ...
# 3           Atlantic/Reykjavik           2025-06-19 19:00Z  ...
# 4                Europe/Athens           2025-06-19 19:25Z  ...
# ..                         ...                         ...  ...
# 265              Europe/London           2025-06-20 09:00Z  ...
# 266              Europe/London           2025-06-20 08:50Z  ...
# 267              Europe/Athens           2025-06-20 06:40Z  ...
# 268              Europe/Warsaw           2025-06-20 07:45Z  ...
# 269             America/Panama           2025-06-19 23:50Z  ...
#
#     arrival.quality aircraft.reg aircraft.modeS               aircraft.model  \
# 0     [Basic, Live]       PH-YHA         4866ED  Airbus A321-200 (Sharklets)
# 1     [Basic, Live]       PH-YHY         4866DE  Airbus A321-200 (Sharklets)
# 2     [Basic, Live]       PH-HSK         485122    Boeing 737-800 (winglets)
# 3     [Basic, Live]       PH-HSI         485009    Boeing 737-800 (winglets)
# 4     [Basic, Live]       PH-HSG         484F6D    Boeing 737-800 (winglets)
# ..              ...          ...            ...                          ...
# 265   [Basic, Live]       PH-EXV         485871                  Embraer 190
# 266   [Basic, Live]       PH-EXN         4855D0                  Embraer 175
# 267   [Basic, Live]       PH-YHB         4866EE  Airbus A321-200 (Sharklets)
# 268   [Basic, Live]       OE-LSV         440075  Airbus A321-200 (Sharklets)
# 269   [Basic, Live]       PH-BVK         485000             Boeing 777-300ER
#
#     airline.name airline.iata airline.icao departure.runwayTime.utc  \
# 0      Transavia           HV          TRA                      NaN
# 1      Transavia           HV          TRA                      NaN
# 2      Transavia           HV          TRA                      NaN
# 3      Transavia           HV          TRA        2025-06-19 19:30Z
# 4      Transavia           HV          TRA                      NaN
# ..           ...          ...          ...                      ...
# 265          KLM           KL          KLM                      NaN
# 266          KLM           KL          KLM                      NaN
# 267    Transavia           HV          TRA                      NaN
# 268      easyJet           U2          EZY        2025-06-20 08:22Z
# 269          KLM           KL          KLM                      NaN
#
#     departure.runwayTime.local departure.runway
# 0                          NaN              NaN
# 1                          NaN              NaN
# 2                          NaN              NaN
# 3       2025-06-19 19:30+00:00              NaN
# 4                          NaN              NaN
# ..                         ...              ...
# 265                        NaN               09
# 266                        NaN              NaN
# 267                        NaN              NaN
# 268     2025-06-20 10:22+02:00               25
# 269                        NaN              NaN
#
# [270 rows x 36 columns]

# %%
list_of_icaos = airport_df["icao"].to_list()
list_city_ids = airport_df["city_id"].to_list()

# %%
def Get_Flight_Data(icao_codes, city_ids):
    flight_data_dfs = []
    for icao,city_id in zip(icao_codes, city_ids):

        url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/2025-06-20T00:00/2025-06-20T12:00"

        querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"false","withCodeshared":"false","withCargo":"false","withPrivate":"false","withLocation":"false"}

        headers = {
            "x-rapidapi-key": accessKeys.API_flight_key,
            "x-rapidapi-host": "aerodatabox.p.rapidapi.com"
        }

        response = requests.get(url, headers=headers, params=querystring)
        if(response.status_code != 200):
            continue

        flights_df = pd.json_normalize(response.json()["arrivals"])
        flights_df["arrival_icao"] = icao
        flight_data_dfs.append(flights_df)

    return pd.concat(flight_data_dfs,axis=0)

# %%
flight_data_df = Get_Flight_Data(list_of_icaos, list_city_ids)

# %%
flight_data_df
# Out:
#      number callSign       status codeshareStatus  isCargo  \
# 0   DJ 6228  SRR6228  Approaching      IsOperator    False
# 1    5O 5DN   FPO5DN      Arrived      IsOperator    False
# 2    HU 489   CHH489      Arrived      IsOperator    False
# 3    XQ 966    SXS3Z      Arrived      IsOperator    False
# 4   EW 6900  EWG6900      Arrived      IsOperator    False
# ..      ...      ...          ...             ...      ...
# 38  U2 8439  EZY45FV  Approaching      IsOperator    False
# 39  V7 2659      NaN      Unknown         Unknown    False
# 40  KL 1465   KLM99B     Expected      IsOperator    False
# 41  FR 5794  RYR3563     Expected      IsOperator    False
# 42  AH 1068  DAH1068      Unknown      IsOperator    False
#
#    departure.airport.icao departure.airport.iata departure.airport.name  \
# 0                    EDDK                    CGN                Cologne
# 1                    LFPG                    CDG                  Paris
# 2                    ZBAA                    PEK                Beijing
# 3                    LTBJ                    ADB                  İzmir
# 4                     NaN                    NaN                Unknown
# ..                    ...                    ...                    ...
# 38                   EGKK                    LGW                 London
# 39                   DAOO                    ORN                   Oran
# 40                   EHAM                    AMS              Amsterdam
# 41                   LPFR                    FAO                   Faro
# 42                   DAOO                    ORN                   Oran
#
#    departure.airport.timeZone departure.quality  ... arrival.runwayTime.utc  \
# 0               Europe/Berlin                []  ...                    NaN
# 1                Europe/Paris     [Basic, Live]  ...      2025-06-20 03:50Z
# 2               Asia/Shanghai           [Basic]  ...                    NaN
# 3             Europe/Istanbul     [Basic, Live]  ...                    NaN
# 4                         NaN                []  ...      2025-06-20 04:30Z
# ..                        ...               ...  ...                    ...
# 38              Europe/London     [Basic, Live]  ...                    NaN
# 39             Africa/Algiers           [Basic]  ...                    NaN
# 40           Europe/Amsterdam     [Basic, Live]  ...                    NaN
# 41              Europe/Lisbon     [Basic, Live]  ...                    NaN
# 42             Africa/Algiers           [Basic]  ...                    NaN
#
#    arrival.runwayTime.local arrival.runway departure.terminal  \
# 0                       NaN            NaN                NaN
# 1    2025-06-20 05:50+02:00            25R                NaN
# 2                       NaN            NaN                  2
# 3                       NaN            NaN                  I
# 4    2025-06-20 06:30+02:00            25L                NaN
# ..                      ...            ...                ...
# 38                      NaN            NaN                  N
# 39                      NaN            NaN                NaN
# 40                      NaN            NaN                  1
# 41                      NaN            NaN                  1
# 42                      NaN            NaN                NaN
#
#    arrival.terminal arrival.gate arrival.baggageBelt departure.checkInDesk  \
# 0               NaN          NaN                 NaN                   NaN
# 1               NaN          NaN                 NaN                   NaN
# 2                 1          N02                  A3                   NaN
# 3                 1          N02                  A4                    10
# 4               NaN          NaN                 NaN                   NaN
# ..              ...          ...                 ...                   ...
# 38                2          NaN                 NaN                   NaN
# 39                1          NaN                 NaN                   NaN
# 40                1          NaN                 NaN                   6-8
# 41                2          NaN                 NaN                   NaN
# 42                1          NaN                 NaN                   NaN
#
#    departure.gate arrival_icao
# 0             NaN         EDDB
# 1             NaN         EDDB
# 2             NaN         EDDB
# 3             101         EDDB
# 4             NaN         EDDB
# ..            ...          ...
# 38            NaN         LFML
# 39            NaN         LFML
# 40            C12         LFML
# 41            NaN         LFML
# 42            NaN         LFML
#
# [1226 rows x 38 columns]

# %% [markdown]
# # Send Data back to SQL

# %% [markdown]
# ## Clean Airport Dataframe

# %%
# Check if all the datatypes are correct
airport_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 0
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   icao              15 non-null     object
#  1   iata              15 non-null     object
#  2   name              15 non-null     object
#  3   shortName         15 non-null     object
#  4   municipalityName  15 non-null     object
#  5   countryCode       15 non-null     object
#  6   timeZone          15 non-null     object
#  7   location.lat      15 non-null     float64
#  8   location.lon      15 non-null     float64
#  9   city_id           15 non-null     int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.3+ KB

# %%
airport_df_fin = pd.DataFrame(airport_df[["icao", "iata", "name", "countryCode", "timeZone", "location.lat", "location.lon", "city_id"]])

# %% [markdown]
# The column names need to align with the column names of SQL

# %%
airport_df_fin = airport_df_fin.rename(columns={"location.lat":"latitude", "location.lon":"longitude"})

# %%
airport_df_fin.to_sql("airport", 
                  if_exists="append", 
                  con=connection_string, 
                  index=False)
# Out:
# 15

# %% [markdown]
# ## Clean Flights Dataframe

# %%
flight_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1226 entries, 0 to 42
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   number                         1226 non-null   object
#  1   callSign                       1096 non-null   object
#  2   status                         1226 non-null   object
#  3   codeshareStatus                1226 non-null   object
#  4   isCargo                        1226 non-null   bool
#  5   departure.airport.icao         1205 non-null   object
#  6   departure.airport.iata         1205 non-null   object
#  7   departure.airport.name         1226 non-null   object
#  8   departure.airport.timeZone     1205 non-null   object
#  9   departure.quality              1226 non-null   object
#  10  arrival.scheduledTime.utc      1226 non-null   object
#  11  arrival.scheduledTime.local    1226 non-null   object
#  12  arrival.revisedTime.utc        975 non-null    object
#  13  arrival.revisedTime.local      975 non-null    object
#  14  arrival.quality                1226 non-null   object
#  15  aircraft.reg                   1088 non-null   object
#  16  aircraft.modeS                 1101 non-null   object
#  17  aircraft.model                 1220 non-null   object
#  18  airline.name                   1226 non-null   object
#  19  airline.iata                   1200 non-null   object
#  20  airline.icao                   1205 non-null   object
#  21  departure.scheduledTime.utc    1175 non-null   object
#  22  departure.scheduledTime.local  1175 non-null   object
#  23  departure.revisedTime.utc      732 non-null    object
#  24  departure.revisedTime.local    732 non-null    object
#  25  departure.runwayTime.utc       592 non-null    object
#  26  departure.runwayTime.local     592 non-null    object
#  27  departure.runway               344 non-null    object
#  28  arrival.runwayTime.utc         310 non-null    object
#  29  arrival.runwayTime.local       310 non-null    object
#  30  arrival.runway                 348 non-null    object
#  31  departure.terminal             678 non-null    object
#  32  arrival.terminal               1097 non-null   object
#  33  arrival.gate                   160 non-null    object
#  34  arrival.baggageBelt            328 non-null    object
#  35  departure.checkInDesk          315 non-null    object
#  36  departure.gate                 359 non-null    object
#  37  arrival_icao                   1226 non-null   object
# dtypes: bool(1), object(37)
# memory usage: 365.2+ KB

# %%
# Number, Callsign, status, departure.airport.icao, airline.name, arrival.scheduledTime.local, arrival_icao

# %%
flights_df_fin = flight_data_df[["number", "callSign", "status", "departure.airport.icao", "airline.name", "arrival.scheduledTime.local", "arrival_icao"]]

# %%
flights_df_fin = flights_df_fin.rename(columns={"departure.airport.icao":"departure_icao", "airline.name":"airline", "arrival.scheduledTime.local":"arrival_time_local"})

# %%
flights_df_fin
# Out:
#      number callSign       status departure_icao              airline  \
# 0   DJ 6228  SRR6228  Approaching           EDDK         Star Air A/S
# 1    5O 5DN   FPO5DN      Arrived           LFPG  ASL Airlines France
# 2    HU 489   CHH489      Arrived           ZBAA               Hainan
# 3    XQ 966    SXS3Z      Arrived           LTBJ          Sun Express
# 4   EW 6900  EWG6900      Arrived            NaN            Eurowings
# ..      ...      ...          ...            ...                  ...
# 38  U2 8439  EZY45FV  Approaching           EGKK              easyJet
# 39  V7 2659      NaN      Unknown           DAOO              Volotea
# 40  KL 1465   KLM99B     Expected           EHAM                  KLM
# 41  FR 5794  RYR3563     Expected           LPFR              Ryanair
# 42  AH 1068  DAH1068      Unknown           DAOO          Air Algerie
#
#         arrival_time_local arrival_icao
# 0   2025-06-20 05:25+02:00         EDDB
# 1   2025-06-20 05:53+02:00         EDDB
# 2   2025-06-20 06:45+02:00         EDDB
# 3   2025-06-20 06:30+02:00         EDDB
# 4   2025-06-20 06:30+02:00         EDDB
# ..                     ...          ...
# 38  2025-06-20 11:00+02:00         LFML
# 39  2025-06-20 11:00+02:00         LFML
# 40  2025-06-20 11:30+02:00         LFML
# 41  2025-06-20 11:40+02:00         LFML
# 42  2025-06-20 11:45+02:00         LFML
#
# [1226 rows x 7 columns]

# %%
flights_df_fin.to_sql("flights", 
                  if_exists="append", 
                  con=connection_string,
                  index=False)
# Out:
# 1226
